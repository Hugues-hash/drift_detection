# %%
import yfinance as yf
import pandas as pd
from pathlib import Path

# %%
data = yf.download("SPY", start="2005-01-01")
data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker            SPY        SPY        SPY        SPY       SPY
# Date
# 2005-01-03  81.606003  82.596399  81.334660  82.460725  55748000
# 2005-01-04  80.608803  81.768787  80.344245  81.714518  69167600
# 2005-01-05  80.052582  80.893740  80.045797  80.547777  65667300
# 2005-01-06  80.459557  80.825868  80.222134  80.344238  47814700
# 2005-01-07  80.344231  80.880131  80.133937  80.703757  55847700

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 5317 entries, 2005-01-03 to 2026-02-20
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   (Close, SPY)   5317 non-null   float64
#  1   (High, SPY)    5317 non-null   float64
#  2   (Low, SPY)     5317 non-null   float64
#  3   (Open, SPY)    5317 non-null   float64
#  4   (Volume, SPY)  5317 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 249.2 KB

# %%
data.columns
# Out:
# MultiIndex([( 'Close', 'SPY'),
#             (  'High', 'SPY'),
#             (   'Low', 'SPY'),
#             (  'Open', 'SPY'),
#             ('Volume', 'SPY')],
#            names=['Price', 'Ticker'])

# %%
data_dir = Path("../data/raw")
data_dir.mkdir(parents=True, exist_ok=True)
data.to_csv(data_dir / "spy_price.csv")

# %%
data.tail()
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker             SPY         SPY         SPY         SPY       SPY
# Date
# 2026-02-13  681.750000  686.280029  677.520020  681.690002  96267500
# 2026-02-17  682.849976  684.940002  675.780029  680.140015  81354700
# 2026-02-18  686.289978  689.150024  682.830017  684.020020  73570300
# 2026-02-19  684.479980  686.179993  681.549988  683.840027  58649400
# 2026-02-20  689.429993  690.059998  681.729980  682.320007  99952100

# %%
data.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker          SPY          SPY          SPY          SPY           SPY
# count   5317.000000  5317.000000  5317.000000  5317.000000  5.317000e+03
# mean     228.528229   229.753707   227.120534   228.496898  1.228571e+08
# std      160.530527   161.284590   159.625361   160.502510  8.988186e+07
# min       49.944588    51.330511    49.203962    49.827258  1.527000e+07
# 25%       98.687073    99.214773    98.009811    98.679955  6.521290e+07
# 50%      172.532761   173.429595   171.584617   172.535365  9.210300e+07
# 75%      325.553009   327.625804   324.270275   326.027059  1.505247e+08
# max      695.489990   697.840027   693.940002   697.049988  8.710263e+08

# %% [markdown]
# ### Time integrity

# %%
# check if time is sorted
data.index.is_monotonic_increasing
# Out:
# True

# %%
#  check duplicate stamps
data.index.duplicated().sum()
# Out:
# np.int64(0)

# %%
# plot closing price
data["Close"].plot(title="SPY Closing Price")
# Out:
# <Axes: title={'center': 'SPY Closing Price'}, xlabel='Date'>

# %%
# transform to returns
data["Returns"] = data["Close"].pct_change()
data["Returns"].plot(title="SPY Returns", ylabel="Returns", xlabel="Date")
# Out:
# <Axes: title={'center': 'SPY Returns'}, xlabel='Date', ylabel='Returns'>

# %% [markdown]
# In general throught the years, the returns oxcillate around 0. Except around 2008, 2024 and 2025 which correspond to unstability periods.

# %%
data['Returns'].describe()
# Out:
# count    5316.000000
# mean        0.000473
# std         0.011979
# min        -0.109424
# 25%        -0.003936
# 50%         0.000716
# 75%         0.005797
# max         0.145198
# Name: Returns, dtype: float64

# %%
# rolling statistics
data["Rolling_Mean"] = data["Returns"].rolling(window=252).mean()
data["Rolling_Std"] = data["Returns"].rolling(window=252).std()

data[["Rolling_Mean", "Rolling_Std"]].plot(title="SPY Rolling average and Rolling volatility", subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %% [markdown]
# The rolling mean exhibits temporary deviations during crisis periods, largely driven by clusters of extreme returns. However, these shifts appear less persistent than the pronounced and sustained changes observed in rolling volatility, suggesting that non-stationarity in returns is primarily variance-driven.

# %% [markdown]
# ### Distribution sanity checks

# %%
data["Returns"].hist(bins=100)
# Out:
# <Axes: >

# %%
data["Returns"].skew()
# Out:
# np.float64(-0.0013393458135009977)

# %%
data["Returns"].kurtosis()
# Out:
# np.float64(15.411261120233153)

# %%
returns_2008 = data.loc["2007":"2009", "Returns"]
returns_2020 = data.loc["2019":"2021", "Returns"]

returns_2008.hist(alpha=0.5, legend=True, bins=100)
returns_2020.hist(alpha=0.5, bins=100)
# Out:
# <Axes: >

# %% [markdown]
# Return distribution in 2008 is more dispersed and heavy-tailed than in 2024. This indicates higher volatility and tail risk during the 2008 crisis.

# %% [markdown]
# SPY returns show variance and distribution changes over time. This motivates distribution shifts detection and model monitoring.

# %% [markdown]
# #### Can we detect and characterise changes in the statistical properties of financial returns over time?
#
# we will detect variance and distribution.
#
# Null hypothesis: returns are stationary over time

# %% [markdown]
# ### Statistical tests: quantify changes
